# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from pycbc import psd
from simple_pe.param_est import find_metric_and_eigendirections
# Out:
# /home/ben.patterson/.conda/envs/igwn_simple_pe/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# import logging
# _logger = logging.getLogger('PESummary')
# _logger.setLevel(logging.CRITICAL + 10)

# %%
# Defines PSD settings
ifos = ['H1', 'L1', 'V1']

psds = {'H1': 'aLIGOMidHighSensitivityP1200087',
        'L1': 'aLIGOMidHighSensitivityP1200087',
        'V1': 'AdVMidHighSensitivityP1200087',
        'f_low': 20,
        'f_high': 8192,
        'length': 32
        }

snr = 18

psds['delta_f'] = 1. / psds['length']

approximant = 'EccentricTD'

# %%
# Calculates PSD
pycbc_psd = {}
for ifo in ifos:
    pycbc_psd[ifo] = psd.analytical.from_string(psds[ifo], psds['length'] * psds['f_high'] + 1, psds['delta_f'],
                                                psds['f_low'])

pycbc_psd['harm'] = 3. / sum([1. / pycbc_psd[ifo] for ifo in ifos])
# Out:
# /home/ben.patterson/.conda/envs/igwn_simple_pe/lib/python3.10/site-packages/pycbc/types/array.py:390: RuntimeWarning: divide by zero encountered in divide
#   return self._data.__rtruediv__(other)

# %%
# Uses simple-pe to calculate approx. of posterior dist. using metric, eigendirections
pars = {'chirp_mass':12.167, 'symmetric_mass_ratio':2/9, 'eccentricity': 0.1, 'spin_1z': 0, 'spin_2z': 0, 'f_ref':20}
par_dirs = ['chirp_mass', 'eccentricity']

g_chirp_e = find_metric_and_eigendirections(pars, par_dirs, snr=snr, f_low=psds['f_low'], psd=pycbc_psd['harm'], approximant=approximant)
# Out:
# 2023-10-18  13:06:40 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:06:41 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:06:43 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:06:44 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:06:45 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:06:46 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:07:50 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:07:51 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:07:52 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:07:53 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:07:54 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:07:56 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:07:57 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:07:58 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:07:59 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:01 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:02 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:03 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:04 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:05 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:07 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:08 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:09 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:10 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:12 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:13 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:14 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:15 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:17 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:18 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:19 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:20 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:08:21 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:24 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:25 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:26 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:28 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:29 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:30 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:31 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:32 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:34 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:35 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:36 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:37 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:39 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:40 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:41 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:42 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:43 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:45 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:46 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:47 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:48 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:50 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:51 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:09:51 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:10:55 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:10:56 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:10:57 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:10:59 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:00 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:01 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:02 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:04 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:05 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:06 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:07 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:09 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:10 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:11 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:12 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:14 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:15 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:16 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:17 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:18 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:20 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:21 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:11:22 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator: fRef = 20.000000 must be < Schwar. ISCO=19.349545
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralEccentricTD.c:1049): Invalid argument
# XLAL Error - XLALSimInspiralChooseTDWaveform_legacy (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorLegacy.c:566): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_td_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:136): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_fd_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:554): Internal function call failed: Invalid argument
# 2023-10-18  13:11:22 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:25 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:26 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:28 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:29 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:30 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:31 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:33 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:34 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:35 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:36 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:38 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:39 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:40 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:41 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:43 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:44 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:45 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:46 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:48 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:49 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:50 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:51 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:12:52 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator: fRef = 20.000000 must be < Schwar. ISCO=15.899414
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralEccentricTD.c:1049): Invalid argument
# XLAL Error - XLALSimInspiralChooseTDWaveform_legacy (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorLegacy.c:566): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_td_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:136): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_fd_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:554): Internal function call failed: Invalid argument
# 2023-10-18  13:12:52 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:13:56 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:13:57 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:13:58 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:00 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:01 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:02 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:03 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:05 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:06 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:07 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:08 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:10 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:11 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:12 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:13 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:15 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:14:16 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator: fRef = 20.000000 must be < Schwar. ISCO=13.493456
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralEccentricTD.c:1049): Invalid argument
# XLAL Error - XLALSimInspiralChooseTDWaveform_legacy (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorLegacy.c:566): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_td_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:136): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_fd_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:554): Internal function call failed: Invalid argument
# 2023-10-18  13:14:16 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:19 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:20 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:22 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:23 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:24 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:25 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:27 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:28 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:29 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:30 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:32 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:33 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:34 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:35 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:37 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:38 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:15:39 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator: fRef = 20.000000 must be < Schwar. ISCO=11.719949
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralEccentricTD.c:1049): Invalid argument
# XLAL Error - XLALSimInspiralChooseTDWaveform_legacy (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorLegacy.c:566): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_td_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:136): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_fd_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:554): Internal function call failed: Invalid argument
# 2023-10-18  13:15:39 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:42 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:44 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:45 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:46 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:47 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:48 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:50 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:51 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:52 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:53 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:55 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:56 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:57 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:16:58 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:17:00 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:17:01 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:17:02 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator: fRef = 20.000000 must be < Schwar. ISCO=10.358487
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralEccentricTD.c:1049): Invalid argument
# XLAL Error - XLALSimInspiralChooseTDWaveform_legacy (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorLegacy.c:566): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_td_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:136): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_fd_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:554): Internal function call failed: Invalid argument
# 2023-10-18  13:17:02 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:06 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:07 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:08 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:09 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:10 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:12 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:13 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:14 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:15 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:17 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:18 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:19 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:20 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:21 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:23 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:24 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:18:25 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator: fRef = 20.000000 must be < Schwar. ISCO=9.280415
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralEccentricTD.c:1049): Invalid argument
# XLAL Error - XLALSimInspiralChooseTDWaveform_legacy (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorLegacy.c:566): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_td_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:136): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_fd_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:554): Internal function call failed: Invalid argument
# 2023-10-18  13:18:25 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:29 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:30 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:31 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:33 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:34 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:35 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:36 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:37 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:39 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:40 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:41 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:42 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:44 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:45 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:46 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:47 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:19:49 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator: fRef = 20.000000 must be < Schwar. ISCO=8.405593
# XLAL Error - XLALSimInspiralEccentricTDPNGenerator (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralEccentricTD.c:1049): Invalid argument
# XLAL Error - XLALSimInspiralChooseTDWaveform_legacy (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorLegacy.c:566): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_td_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:136): Internal function call failed: Invalid argument
# XLAL Error - generate_conditioned_fd_waveform_from_td (/home/conda/feedstock_root/build_artifacts/lalsimulation-split_1692629218759/work/lib/LALSimInspiralGeneratorConditioning.c:554): Internal function call failed: Invalid argument
# 2023-10-18  13:19:49 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:20:52 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:20:53 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:20:54 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:20:56 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:20:57 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:20:58 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:20:59 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:00 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:02 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:03 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:04 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:05 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:07 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:08 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:09 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:10 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:12 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:13 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:14 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:15 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default
# 2023-10-18  13:21:16 PESummary WARNING : Could not find f_final in input file and one was not passed from the command line. Using 1024.0Hz as default

# %%
# Calculates 90% ellipse
chirp_e_ellipse = g_chirp_e.generate_ellipse()

# %%
# Calculates samples and match/pdf at each
chirp_e_mat = g_chirp_e.generate_match_grid(npts=21, scale=1.3)
chirp_e_p = np.exp(-snr**2/2 * (1 - chirp_e_mat['match']))

# %%
# Plots figure
plt.figure(figsize=(12, 9))
plt.tricontourf(chirp_e_mat.samples[0], chirp_e_mat.samples[1], chirp_e_p, levels=np.linspace(0, 1, 21))
plt.xlabel(chirp_e_mat.keys()[0])
plt.ylabel(chirp_e_mat.keys()[1])
plt.colorbar(label='pdf')
plt.plot(chirp_e_ellipse.samples[0], chirp_e_ellipse.samples[1], 'r')
plt.grid()
# plt.xlim([0,1])
# plt.ylim([0.15, 0.25])
plt.show()
