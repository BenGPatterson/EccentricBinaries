# %%
import numpy as np
import matplotlib.pyplot as plt
from calcwf import const_eff_chirp_bose

# %%
e_vals = np.linspace(0,0.2,100)
chirp_vals = const_eff_chirp_bose(0.1, 24, e_vals)

# %%
plt.plot(chirp_vals, e_vals**2)
