# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle

# %% [markdown]
# # 2D

# %%
with open(os.path.join('grid_data_4d', 'dataslot_1', 'all_matches'), 'rb') as fp:
        grid_data_1 = pickle.load(fp)

# Find min and max
for key in list(grid_data_1.keys()):
    if key != 'metadata' and 'phase' not in key:
        grid_data_1[f'{key}_max'] = np.nanmax(np.array(grid_data_1[key]), axis=1)
        grid_data_1[f'{key}_min'] = np.nanmin(np.array(grid_data_1[key]), axis=1)

# %%
# Plot
plt.figure(figsize=(0.75*6.4, 0.75*4.8))
e_vals = grid_data_1['metadata']['degen_params']['ecc10']
fid_e = grid_data_1['metadata']['fid_params']['ecc10sqrd']**0.5
plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
high_harm_min = np.sqrt(1-grid_data_1['h0_max']**2)/grid_data_1['h0_max']
high_harm_max = np.sqrt(1-grid_data_1['h0_min']**2)/grid_data_1['h0_min']
plt.plot(e_vals, high_harm_max, c='k', zorder=4/5, label='$\\rho_{\\perp}$')
plt.plot(e_vals, high_harm_min, c='k', zorder=4/5)
plt.fill_between(e_vals, high_harm_min, high_harm_max, color='k', zorder=4/5, alpha=0.3)
plt.plot(e_vals, grid_data_1['h1_h0_max'], c='C0', zorder=2/5, label='$\\rho_1$')
plt.plot(e_vals, grid_data_1['h1_h0_min'], c='C0', zorder=2/5)
plt.fill_between(e_vals, grid_data_1['h1_h0_min'], 
                 grid_data_1['h1_h0_max'], color='C0', zorder=2/5, alpha=0.3)
plt.plot(e_vals, grid_data_1['h-1_h0_max'], c='C1', zorder=1/5, label='$\\rho_{-1}$')
plt.plot(e_vals, grid_data_1['h-1_h0_min'], c='C1', zorder=1/5)
plt.fill_between(e_vals, grid_data_1['h-1_h0_min'], 
                 grid_data_1['h-1_h0_max'], color='C1', zorder=1/5, alpha=0.3)
plt.plot(e_vals, grid_data_1['h1_h-1_h0_max'], c='C2', zorder=3/5, label='$\\sqrt{\\rho_1^2+\\rho_{-1}^2}$')
plt.plot(e_vals, grid_data_1['h1_h-1_h0_min'], c='C2', zorder=3/5)
plt.fill_between(e_vals, grid_data_1['h1_h-1_h0_min'], 
                 grid_data_1['h1_h-1_h0_max'], color='C2', zorder=3/5, alpha=0.3)
plt.legend(frameon=False, loc=(0.25,0.50))
plt.xlim(0,0.4)
plt.ylim(0,0.85)
plt.xlabel('$e_{10}$')
# Out:
# Text(0.5, 0, '$e_{10}$')

# %% [markdown]
# # 3D

# %%
with open(os.path.join('grid_data_4d', 'dataslot_2', 'all_matches'), 'rb') as fp:
        grid_data_2 = pickle.load(fp)

# Find min and max
for key in list(grid_data_2.keys()):
    if key != 'metadata' and 'phase' not in key:
        grid_data_2[f'{key}_max'] = np.nanmax(np.array(grid_data_2[key]), axis=1)
        grid_data_2[f'{key}_min'] = np.nanmin(np.array(grid_data_2[key]), axis=1)

# %%
# Plot for each combination
plt.figure(figsize=(0.75*6.4, 0.75*4.8))
e_vals = grid_data_2['metadata']['degen_params']['ecc10']
fid_e = grid_data_2['metadata']['fid_params']['ecc10sqrd']**0.5
plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
high_harm_min = np.sqrt(1-grid_data_2['h0_max']**2)/grid_data_2['h0_max']
high_harm_max = np.sqrt(1-grid_data_2['h0_min']**2)/grid_data_2['h0_min']
plt.plot(e_vals, high_harm_max, c='k', zorder=4/5, label='$\\rho_{\\perp}$')
plt.plot(e_vals, high_harm_min, c='k', zorder=4/5)
plt.fill_between(e_vals, high_harm_min, high_harm_max, color='k', zorder=4/5, alpha=0.3)
plt.plot(e_vals, grid_data_2['h1_h0_max'], c='C0', zorder=2/5, label='$\\rho_1$')
plt.plot(e_vals, grid_data_2['h1_h0_min'], c='C0', zorder=2/5)
plt.fill_between(e_vals, grid_data_2['h1_h0_min'], 
                 grid_data_2['h1_h0_max'], color='C0', zorder=2/5, alpha=0.3)
plt.plot(e_vals, grid_data_2['h-1_h0_max'], c='C1', zorder=1/5, label='$\\rho_{-1}$')
plt.plot(e_vals, grid_data_2['h-1_h0_min'], c='C1', zorder=1/5)
plt.fill_between(e_vals, grid_data_2['h-1_h0_min'], 
                 grid_data_2['h-1_h0_max'], color='C1', zorder=1/5, alpha=0.3)
plt.plot(e_vals, grid_data_2['h1_h-1_h0_max'], c='C2', zorder=3/5, label='$\\sqrt{\\rho_1^2+\\rho_{-1}^2}$')
plt.plot(e_vals, grid_data_2['h1_h-1_h0_min'], c='C2', zorder=3/5)
plt.fill_between(e_vals, grid_data_2['h1_h-1_h0_min'], 
                 grid_data_2['h1_h-1_h0_max'], color='C2', zorder=3/5, alpha=0.3)
plt.legend(frameon=False, loc=(0.25,0.50))
plt.xlim(0,0.4)
plt.ylim(0,0.85)
plt.xlabel('$e_{10}$')
# Out:
# Text(0.5, 0, '$e_{10}$')

# %% [markdown]
# # 4D

# %%
with open(os.path.join('grid_data_4d', 'dataslot_0', 'all_matches'), 'rb') as fp:
        grid_data_0 = pickle.load(fp)

# Find min and max
for key in list(grid_data_0.keys()):
    if key != 'metadata' and 'phase' not in key:
        grid_data_0[f'{key}_max'] = np.nanmax(np.array(grid_data_0[key]), axis=1)
        grid_data_0[f'{key}_min'] = np.nanmin(np.array(grid_data_0[key]), axis=1)

# %%
# Plot for each combination
plt.figure(figsize=(0.75*6.4, 0.75*4.8))
e_vals = grid_data_0['metadata']['degen_params']['ecc10']
fid_e = grid_data_0['metadata']['fid_params']['ecc10sqrd']**0.5
plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
high_harm_min = np.sqrt(1-grid_data_0['h0_max']**2)/grid_data_0['h0_max']
high_harm_max = np.sqrt(1-grid_data_0['h0_min']**2)/grid_data_0['h0_min']
plt.plot(e_vals, high_harm_max, c='k', zorder=4/5, label='$\\rho_{\\perp}$')
plt.plot(e_vals, high_harm_min, c='k', zorder=4/5)
plt.fill_between(e_vals, high_harm_min, high_harm_max, color='k', zorder=4/5, alpha=0.3)
plt.plot(e_vals, grid_data_0['h1_h0_max'], c='C0', zorder=2/5, label='$\\rho_1$')
plt.plot(e_vals, grid_data_0['h1_h0_min'], c='C0', zorder=2/5)
plt.fill_between(e_vals, grid_data_0['h1_h0_min'], 
                 grid_data_0['h1_h0_max'], color='C0', zorder=2/5, alpha=0.3)
plt.plot(e_vals, grid_data_0['h-1_h0_max'], c='C1', zorder=1/5, label='$\\rho_{-1}$')
plt.plot(e_vals, grid_data_0['h-1_h0_min'], c='C1', zorder=1/5)
plt.fill_between(e_vals, grid_data_0['h-1_h0_min'], 
                 grid_data_0['h-1_h0_max'], color='C1', zorder=1/5, alpha=0.3)
plt.plot(e_vals, grid_data_0['h1_h-1_h0_max'], c='C2', zorder=3/5, label='$\\sqrt{\\rho_1^2+\\rho_{-1}^2}$')
plt.plot(e_vals, grid_data_0['h1_h-1_h0_min'], c='C2', zorder=3/5)
plt.fill_between(e_vals, grid_data_0['h1_h-1_h0_min'], 
                 grid_data_0['h1_h-1_h0_max'], color='C2', zorder=3/5, alpha=0.3)
plt.legend(frameon=False, loc=(0.25,0.50))
plt.xlim(0,0.4)
plt.ylim(0,0.85)
plt.xlabel('$e_{10}$')
# Out:
# Text(0.5, 0, '$e_{10}$')

# %% [markdown]
# # Different fid_e values in 2D

# %%
with open(os.path.join('grid_data_4d', 'dataslot_4', 'all_matches_1'), 'rb') as fp:
        grid_data_4_1 = pickle.load(fp)

# Find min and max
for key in list(grid_data_4_1.keys()):
    if key != 'metadata' and 'phase' not in key:
        grid_data_4_1[f'{key}_max'] = np.nanmax(np.array(grid_data_4_1[key]), axis=1)
        grid_data_4_1[f'{key}_min'] = np.nanmin(np.array(grid_data_4_1[key]), axis=1)

# %%
# Plot for each combination
plt.figure(figsize=(0.75*6.4, 0.75*4.8))
e_vals = grid_data_4_1['metadata']['degen_params']['ecc10']
fid_e = grid_data_4_1['metadata']['fid_params']['ecc10sqrd']**0.5
plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
high_harm_min = np.sqrt(1-grid_data_4_1['h0_max']**2)/grid_data_4_1['h0_max']
high_harm_max = np.sqrt(1-grid_data_4_1['h0_min']**2)/grid_data_4_1['h0_min']
plt.plot(e_vals, high_harm_max, c='k', zorder=4/5, label='$\\rho_{\\perp}$')
plt.plot(e_vals, high_harm_min, c='k', zorder=4/5)
plt.fill_between(e_vals, high_harm_min, high_harm_max, color='k', zorder=4/5, alpha=0.3)
plt.plot(e_vals, grid_data_4_1['h1_h0_max'], c='C0', zorder=2/5, label='$\\rho_1$')
plt.plot(e_vals, grid_data_4_1['h1_h0_min'], c='C0', zorder=2/5)
plt.fill_between(e_vals, grid_data_4_1['h1_h0_min'], 
                 grid_data_4_1['h1_h0_max'], color='C0', zorder=2/5, alpha=0.3)
plt.plot(e_vals, grid_data_4_1['h-1_h0_max'], c='C1', zorder=1/5, label='$\\rho_{-1}$')
plt.plot(e_vals, grid_data_4_1['h-1_h0_min'], c='C1', zorder=1/5)
plt.fill_between(e_vals, grid_data_4_1['h-1_h0_min'], 
                 grid_data_4_1['h-1_h0_max'], color='C1', zorder=1/5, alpha=0.3)
plt.plot(e_vals, grid_data_4_1['h1_h-1_h0_max'], c='C2', zorder=3/5, label='$\\sqrt{\\rho_1^2+\\rho_{-1}^2}$')
plt.plot(e_vals, grid_data_4_1['h1_h-1_h0_min'], c='C2', zorder=3/5)
plt.fill_between(e_vals, grid_data_4_1['h1_h-1_h0_min'], 
                 grid_data_4_1['h1_h-1_h0_max'], color='C2', zorder=3/5, alpha=0.3)
plt.legend(frameon=False, loc=(0.25,0.50))
plt.xlim(0,0.4)
plt.ylim(0,0.85)
plt.xlabel('$e_{10}$')
# Out:
# Text(0.5, 0, '$e_{10}$')

# %%
with open(os.path.join('grid_data_4d', 'dataslot_4', 'all_matches_2'), 'rb') as fp:
        grid_data_4_2 = pickle.load(fp)

# Find min and max
for key in list(grid_data_4_2.keys()):
    if key != 'metadata' and 'phase' not in key:
        grid_data_4_2[f'{key}_max'] = np.nanmax(np.array(grid_data_4_2[key]), axis=1)
        grid_data_4_2[f'{key}_min'] = np.nanmin(np.array(grid_data_4_2[key]), axis=1)

# %%
# Plot for each combination
plt.figure(figsize=(0.75*6.4, 0.75*4.8))
e_vals = grid_data_4_2['metadata']['degen_params']['ecc10']
fid_e = grid_data_4_2['metadata']['fid_params']['ecc10sqrd']**0.5
plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
high_harm_min = np.sqrt(1-grid_data_4_2['h0_max']**2)/grid_data_4_2['h0_max']
high_harm_max = np.sqrt(1-grid_data_4_2['h0_min']**2)/grid_data_4_2['h0_min']
plt.plot(e_vals, high_harm_max, c='k', zorder=4/5, label='$\\rho_{\\perp}$')
plt.plot(e_vals, high_harm_min, c='k', zorder=4/5)
plt.fill_between(e_vals, high_harm_min, high_harm_max, color='k', zorder=4/5, alpha=0.3)
plt.plot(e_vals, grid_data_4_2['h1_h0_max'], c='C0', zorder=2/5, label='$\\rho_1$')
plt.plot(e_vals, grid_data_4_2['h1_h0_min'], c='C0', zorder=2/5)
plt.fill_between(e_vals, grid_data_4_2['h1_h0_min'], 
                 grid_data_4_2['h1_h0_max'], color='C0', zorder=2/5, alpha=0.3)
plt.plot(e_vals, grid_data_4_2['h-1_h0_max'], c='C1', zorder=1/5, label='$\\rho_{-1}$')
plt.plot(e_vals, grid_data_4_2['h-1_h0_min'], c='C1', zorder=1/5)
plt.fill_between(e_vals, grid_data_4_2['h-1_h0_min'], 
                 grid_data_4_2['h-1_h0_max'], color='C1', zorder=1/5, alpha=0.3)
plt.plot(e_vals, grid_data_4_2['h1_h-1_h0_max'], c='C2', zorder=3/5, label='$\\sqrt{\\rho_1^2+\\rho_{-1}^2}$')
plt.plot(e_vals, grid_data_4_2['h1_h-1_h0_min'], c='C2', zorder=3/5)
plt.fill_between(e_vals, grid_data_4_2['h1_h-1_h0_min'], 
                 grid_data_4_2['h1_h-1_h0_max'], color='C2', zorder=3/5, alpha=0.3)
plt.legend(frameon=False, loc=(0.25,0.50))
plt.xlim(0,0.4)
plt.ylim(0,0.85)
plt.xlabel('$e_{10}$')
# Out:
# Text(0.5, 0, '$e_{10}$')

# %%
with open(os.path.join('grid_data_4d', 'dataslot_4', 'all_matches_3'), 'rb') as fp:
        grid_data_4_3 = pickle.load(fp)

# Find min and max
for key in list(grid_data_4_3.keys()):
    if key != 'metadata' and 'phase' not in key:
        grid_data_4_3[f'{key}_max'] = np.nanmax(np.array(grid_data_4_3[key]), axis=1)
        grid_data_4_3[f'{key}_min'] = np.nanmin(np.array(grid_data_4_3[key]), axis=1)

# %%
# Plot for each combination
plt.figure(figsize=(0.75*6.4, 0.75*4.8))
e_vals = grid_data_4_3['metadata']['degen_params']['ecc10']
fid_e = grid_data_4_3['metadata']['fid_params']['ecc10sqrd']**0.5
plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
high_harm_min = np.sqrt(1-grid_data_4_3['h0_max']**2)/grid_data_4_3['h0_max']
high_harm_max = np.sqrt(1-grid_data_4_3['h0_min']**2)/grid_data_4_3['h0_min']
plt.plot(e_vals, high_harm_max, c='k', zorder=4/5, label='$\\rho_{\\perp}$')
plt.plot(e_vals, high_harm_min, c='k', zorder=4/5)
plt.fill_between(e_vals, high_harm_min, high_harm_max, color='k', zorder=4/5, alpha=0.3)
plt.plot(e_vals, grid_data_4_3['h1_h0_max'], c='C0', zorder=2/5, label='$\\rho_1$')
plt.plot(e_vals, grid_data_4_3['h1_h0_min'], c='C0', zorder=2/5)
plt.fill_between(e_vals, grid_data_4_3['h1_h0_min'], 
                 grid_data_4_3['h1_h0_max'], color='C0', zorder=2/5, alpha=0.3)
plt.plot(e_vals, grid_data_4_3['h-1_h0_max'], c='C1', zorder=1/5, label='$\\rho_{-1}$')
plt.plot(e_vals, grid_data_4_3['h-1_h0_min'], c='C1', zorder=1/5)
plt.fill_between(e_vals, grid_data_4_3['h-1_h0_min'], 
                 grid_data_4_3['h-1_h0_max'], color='C1', zorder=1/5, alpha=0.3)
plt.plot(e_vals, grid_data_4_3['h1_h-1_h0_max'], c='C2', zorder=3/5, label='$\\sqrt{\\rho_1^2+\\rho_{-1}^2}$')
plt.plot(e_vals, grid_data_4_3['h1_h-1_h0_min'], c='C2', zorder=3/5)
plt.fill_between(e_vals, grid_data_4_3['h1_h-1_h0_min'], 
                 grid_data_4_3['h1_h-1_h0_max'], color='C2', zorder=3/5, alpha=0.3)
plt.legend(frameon=False, loc=(0.25,0.50))
plt.xlim(0,0.4)
plt.ylim(0,0.85)
plt.xlabel('$e_{10}$')
# Out:
# Text(0.5, 0, '$e_{10}$')

# %% [markdown]
# # Can we use phase/MA information?

# %%
import time
from pesummary.gw.conversions.mass import component_masses_from_mchirp_q, q_from_eta
from scipy.optimize import minimize
from calcwf import match_hn
from interpolating_match import comb_harm_consistent
from simple_pe.waveforms import make_waveform, generate_eccentric_waveform, gen_component_wfs, shifted_e, shifted_f
import logging
_logger = logging.getLogger('PESummary')
_logger.setLevel(logging.CRITICAL + 10)
from matplotlib import rcParams
rcParams['axes.grid'] = False
rcParams['text.usetex'] = False

# %%
def degen_point(e10, base_dict, fid_dict):
    point_dict = {'ecc10sqrd': e10**2}
    line_dist = (point_dict['ecc10sqrd']-base_dict['ecc10sqrd'])/(fid_dict['ecc10sqrd']-base_dict['ecc10sqrd'])
    for param in ['chirp_mass', 'symmetric_mass_ratio', 'chi_eff']:
        point_dict[param] = line_dist*(fid_dict[param]-base_dict[param])+base_dict[param]
    point_dict['distance'] = 1
    return point_dict

# %%
base_dict = {'chirp_mass': 24, 'symmetric_mass_ratio': 2/9, 'ecc10sqrd': 0, 'chi_eff': 0}
fid_dict = {'ecc10sqrd': 0.01104614916220744, 'chirp_mass': 23.83672299531145, 'symmetric_mass_ratio': 0.22173405611006322, 'chi_eff': -0.012591061294805223}

harm_dict = degen_point(0.2, base_dict, fid_dict)
harms = make_waveform(harm_dict, 1/32, 20, 32*4096//2+1, approximant="TEOBResumS-Dali-Harms", n_ecc_harms=3)
wf_hjs = []
for mode in [0,1,-1]:
    wf_hjs.append(harms[mode].to_timeseries())

# %%
e_val = 0.2
n_MA = 33
MA_vals = np.linspace(0, 2*np.pi, n_MA, endpoint=False)

matches = []
param_dict = degen_point(e_val, base_dict, fid_dict)
param_dict['mass_ratio'] = q_from_eta(param_dict['symmetric_mass_ratio'])
param_dict['inverted_mass_ratio'] = 1/param_dict['mass_ratio']
param_dict['total_mass'] = np.sum(component_masses_from_mchirp_q(param_dict['chirp_mass'], param_dict['mass_ratio']), axis=0)
hs = gen_component_wfs(param_dict['total_mass'], param_dict['inverted_mass_ratio'], param_dict['ecc10sqrd']**0.5,
                       param_dict['chi_eff'], param_dict['chi_eff'], 10, 20, 4096, 0, 0, 1, 32, n_MA)[0]
for h in hs:
    matches.append(match_hn(wf_hjs, h, 10))
matches = np.array(matches)

# %%
phi0 = np.angle(matches[:,0])
phi1 = np.angle(matches[:,1])
phin1 = np.angle(matches[:,2])

diff1 = (phi1-phi0)%(2*np.pi)
diff2 = (phi0-phin1)%(2*np.pi)
avg_diff = ((diff1+diff2)/2)%(2*np.pi)

plt.plot(MA_vals, diff1, label='phi0-phi0')
plt.xlabel('MA')
plt.ylabel('angle')
plt.xlim(0, 2*np.pi)
plt.ylim(0, 2*np.pi)
plt.legend()

# %% [markdown]
# The difference between the first two match angles is very strongly correlated with MA (for an eccentricity exactly the same as the harmonics anyway), suggesting we may be able to use this to find the 'true' mean anomaly of a signal.

# %%
e_vals_e = np.linspace(0.15, 0.25, 75)

matches_e = []
for e_val in e_vals_e:
    param_dict = degen_point(e_val, base_dict, fid_dict)
    param_dict['mass_ratio'] = q_from_eta(param_dict['symmetric_mass_ratio'])
    param_dict['inverted_mass_ratio'] = 1/param_dict['mass_ratio']
    param_dict['total_mass'] = np.sum(component_masses_from_mchirp_q(param_dict['chirp_mass'], param_dict['mass_ratio']), axis=0)
    hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], param_dict['ecc10sqrd']**0.5,
                                         param_dict['chi_eff'], param_dict['chi_eff'], 10, 4096, tlen=32, to_fs=False)
    h = hp - 1j*hc
    matches_e.append(match_hn(wf_hjs, h, 10))
matches_e = np.array(matches_e)

# %%
phi0 = np.angle(matches_e[:,0])%(2*np.pi)
phi1 = np.angle(matches_e[:,1])%(2*np.pi)
phin1 = np.angle(matches_e[:,2])%(2*np.pi)

diff1 = (phi1-phi0)%(2*np.pi)
diff2 = (phi0-phin1)%(2*np.pi)
avg_diff = ((diff1+diff2)/2)%(2*np.pi)

plt.plot(e_vals_e, diff1, label='phi1-phi0')
# plt.plot(e_vals_e, diff2, label='phi0-phin1')
# plt.plot(e_vals_e, avg_diff, label='avg (phi1-phin1)/2')
plt.xlabel('e_10')
plt.ylabel('angle')
plt.xlim(np.min(e_vals_e), np.max(e_vals_e))
plt.ylim(0, 2*np.pi)
plt.legend()

# %% [markdown]
# The angle however changes rapidly with eccentricity, so finding the MA will be tricky without some way of normalising this.

# %%
n_MA = 11
MA_vals_2d = np.linspace(0, 2*np.pi, n_MA, endpoint=False)
e_vals = np.linspace(0.18, 0.22, 11)

matches_2d = []
for e_val in e_vals:
    matches_2d.append([])
    param_dict = degen_point(e_val, base_dict, fid_dict)
    param_dict['mass_ratio'] = q_from_eta(param_dict['symmetric_mass_ratio'])
    param_dict['inverted_mass_ratio'] = 1/param_dict['mass_ratio']
    param_dict['total_mass'] = np.sum(component_masses_from_mchirp_q(param_dict['chirp_mass'], param_dict['mass_ratio']), axis=0)
    hs = gen_component_wfs(param_dict['total_mass'], param_dict['inverted_mass_ratio'], param_dict['ecc10sqrd']**0.5,
                       param_dict['chi_eff'], param_dict['chi_eff'], 10, 20, 4096, 0, 0, 1, 32, n_MA)[0]
    for h in hs:
        matches_2d[-1].append(match_hn(wf_hjs, h, 10))
matches_2d = np.array(matches_2d)

# %%
phi0 = np.angle(matches_2d[:,:,0])%(2*np.pi)
phi1 = np.angle(matches_2d[:,:,1])%(2*np.pi)
phin1 = np.angle(matches_2d[:,:,2])%(2*np.pi)

diff1 = (phi1-phi0)%(2*np.pi)
diff2 = (phi0-phin1)%(2*np.pi)
avg_diff = ((diff1+diff2)/2)%(2*np.pi)

dx = (MA_vals_2d[1]-MA_vals_2d[0])/2
dy = (e_vals[1]-e_vals[0])/2
extent = [MA_vals_2d[0]-dx, MA_vals_2d[-1]+dx, e_vals[0]-dy, e_vals[-1]+dy]
plt.imshow(diff1, extent=extent, aspect='auto', vmin=0, vmax=2*np.pi, cmap='twilight')
plt.axhline(0.2, c='hotpink')
plt.xlabel('MA')
plt.ylabel('e_10')
plt.grid(False)
plt.colorbar(label='angle')

# %% [markdown]
# We can therefore constrain a signal to a line on the surface of this cylinder by measuring the angle (in reality will be some uncertainty from measuring complex SNR of h1), and it would be nice to compute a bunch of waveforms/matches along the degeneracy line at a constant value of this angle.
#
# This angle is related to the MA at merger, meaning to calculate the change in degen params to cause the angle to change by 2pi, we would need to calculate the change in degen params required to shift the envelope at merger by 2pi. This would likely be very tricky analytically, as would involve same pn equations that we looked at (and gave up on) for shifted e and shifted f.
#
# Instead we could generate wf at MA=0 at each point on degen line and match against harmonics. Could then easily calculate MA needed to shift to correct angle, and regenerate and match here. Does therefore require 2 wf calls at each point instead of 1, but this is far easier and could well be more accurate than trying to calculate analytically.
#
# Let's test this second approach here.

# %%
# Target angle and eccentricity
target_ang = np.pi/3
e_val = 0.2

# Generate and match wf at MA=0
param_dict = degen_point(e_val, base_dict, fid_dict)
param_dict['mass_ratio'] = q_from_eta(param_dict['symmetric_mass_ratio'])
param_dict['inverted_mass_ratio'] = 1/param_dict['mass_ratio']
param_dict['total_mass'] = np.sum(component_masses_from_mchirp_q(param_dict['chirp_mass'], param_dict['mass_ratio']), axis=0)
hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], param_dict['ecc10sqrd']**0.5,
                                     param_dict['chi_eff'], param_dict['chi_eff'], 10, 4096, tlen=32, to_fs=False)
h = hp - 1j*hc
match_cplx = match_hn(wf_hjs, h, 10)
diff1 = (np.angle(match_cplx[1])-np.angle(match_cplx[0]))%(2*np.pi)
MA = target_ang - diff1

# Shift to f, e for required MA (using approx eqns w/o correction for now
s_f_2pi =  10 - shifted_f(10, param_dict['ecc10sqrd']**0.5, param_dict['total_mass'], param_dict['inverted_mass_ratio'])
s_f = 10 - s_f_2pi*MA/(2*np.pi)
s_e = shifted_e(s_f, 10, param_dict['ecc10sqrd']**0.5)

# Generate and match wf at required MA
hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], s_e,
                                     param_dict['chi_eff'], param_dict['chi_eff'], s_f, 4096, tlen=32, to_fs=False)
h = hp - 1j*hc
match_cplx = match_hn(wf_hjs, h, 10)
diff1 = (np.angle(match_cplx[1])-np.angle(match_cplx[0]))%(2*np.pi)
print(f'Tried to get to {target_ang}, got to {diff1}')
# Out:
# Tried to get to 1.0471975511965976, got to 1.294392659259179

# %% [markdown]
# This is pretty accurate, and should certainly be enough for our purposes.
#
# Let's calculate the line of constant MA, and constant angle for the min/max lines from dataslot_0.

# %% [markdown]
# ## 1 iteration

# %%
target_ang = np.pi/3

# Get degen line parameters from metadata
base_params = grid_data_0['metadata']['base_params']
fid_params = grid_data_0['metadata']['fid_params']
fid_params['distance'] = 1
e_vals_4d = grid_data_0['metadata']['degen_params']['ecc10']

# Generate harmonics at fid point
harms = make_waveform(fid_params, 1/32, 20, 32*4096//2+1, approximant="TEOBResumS-Dali-Harms", n_ecc_harms=3)
wf_hjs_4d = []
for mode in [0,1,-1]:
    wf_hjs_4d.append(harms[mode].to_timeseries())

rho_1_fracs_0 = []
rho_1_fracs_MA = []
rho_n1_fracs_0 = []
rho_n1_fracs_MA = []
pc_fracs_0 = []
pc_fracs_MA = []
meas_angs_MA = []
# Loop over each point on degen line
for i, e_val in enumerate(e_vals_4d):

    # Generate and match wf at MA=0
    param_dict = degen_point(e_val, base_params, fid_params)
    param_dict['mass_ratio'] = q_from_eta(param_dict['symmetric_mass_ratio'])
    param_dict['inverted_mass_ratio'] = 1/param_dict['mass_ratio']
    param_dict['total_mass'] = np.sum(component_masses_from_mchirp_q(param_dict['chirp_mass'], param_dict['mass_ratio']), axis=0)
    hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], param_dict['ecc10sqrd']**0.5,
                                         param_dict['chi_eff'], param_dict['chi_eff'], 10, 4096, tlen=32, to_fs=False)
    h = hp - 1j*hc
    match_cplx_0 = match_hn(wf_hjs_4d, h, 10)
    meas_ang_0 = (np.angle(match_cplx_0[1])-np.angle(match_cplx_0[0]))%(2*np.pi)
    MA = target_ang - meas_ang_0

    # Shift to f, e for required MA (using approx eqns w/o correction for now
    s_f_2pi =  10 - shifted_f(10, param_dict['ecc10sqrd']**0.5, param_dict['total_mass'], param_dict['inverted_mass_ratio'])
    s_f = 10 - s_f_2pi*MA/(2*np.pi)
    s_e = shifted_e(s_f, 10, param_dict['ecc10sqrd']**0.5)
    
    # Generate and match wf at required MA
    hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], s_e,
                                         param_dict['chi_eff'], param_dict['chi_eff'], s_f, 4096, tlen=32, to_fs=False)
    h = hp - 1j*hc
    match_cplx_MA = match_hn(wf_hjs_4d, h, 10)
    meas_angs_MA.append((np.angle(match_cplx_MA[1])-np.angle(match_cplx_MA[0]))%(2*np.pi))

    # Get phase consistent match fractions of both
    rho_1_fracs_0.append(np.abs(match_cplx_0[1])/np.abs(match_cplx_0[0]))
    rho_1_fracs_MA.append(np.abs(match_cplx_MA[1])/np.abs(match_cplx_MA[0]))
    rho_n1_fracs_0.append(np.abs(match_cplx_0[2])/np.abs(match_cplx_0[0]))
    rho_n1_fracs_MA.append(np.abs(match_cplx_MA[2])/np.abs(match_cplx_MA[0]))
    pc_fracs_0.append(comb_harm_consistent(np.abs(match_cplx_0[:3]), np.angle(match_cplx_0[:3]), harms=[0,1,-1]))
    pc_fracs_MA.append(comb_harm_consistent(np.abs(match_cplx_MA[:3]), np.angle(match_cplx_MA[:3]), harms=[0,1,-1]))

    print(f'\r{i+1} out of {len(e_vals_4d)} done.', end='')
# Out:
# 151 out of 151 done.

# %%
# Metadata
e_vals_mm = grid_data_0['metadata']['degen_params']['ecc10']
fid_e = grid_data_0['metadata']['fid_params']['ecc10sqrd']**0.5

keys = ['h1_h0', 'h-1_h0', 'h1_h-1_h0']
labels = ['$\\rho_1$', '$\\rho_-1$', '$\\sqrt{\\rho_1^2+\\rho_{-1}^2}$']
cs = ['C0', 'C1', 'C2']
fracs_0_list = [rho_1_fracs_0, rho_n1_fracs_0, pc_fracs_0]
fracs_MA_list = [rho_1_fracs_MA, rho_n1_fracs_MA, pc_fracs_MA]
for key, label, c, fracs_0, fracs_MA in zip(keys, labels, cs, fracs_0_list, fracs_MA_list):

    # Plot min/max region
    plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
    plt.plot(e_vals_mm, grid_data_0[f'{key}_max'], c=c, zorder=3/5, label=label)
    plt.plot(e_vals_mm, grid_data_0[f'{key}_min'], c=c, zorder=3/5)
    plt.fill_between(e_vals_mm, grid_data_0[f'{key}_min'], 
                     grid_data_0[f'{key}_max'], color=c, zorder=3/5, alpha=0.3)
    
    # Plot const MA and const ang lines
    plt.plot(e_vals_4d, fracs_0, c='r', alpha=0.7, label='const MA')
    plt.plot(e_vals_4d, fracs_MA, c='k', label='const angle')
    
    # Plot formatting
    plt.legend(frameon=False, loc=(0.35,0.50))
    plt.xlim(0,0.4)
    plt.ylim(0,0.85)
    plt.xlabel('$e_{10}$')
    plt.show()

# Plot all three constant angle lines on same plot
plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
for label, c, fracs_MA in zip(labels, cs, fracs_MA_list):
    plt.plot(e_vals_4d, fracs_MA, c=c, label=label)
plt.legend(frameon=False, loc=(0.35,0.50))
plt.xlim(0,0.4)
plt.ylim(0,0.85)
plt.xlabel('$e_{10}$')
plt.show()

# Plot measured angle at each eccentricity
plt.axhline(target_ang, c='k', ls='dashed', label='target angle')
plt.plot(e_vals_4d, meas_angs_MA, alpha=0.7, label='measured angle')
plt.legend()
plt.xlim(0,0.4)
plt.ylim(target_ang-0.5, target_ang+0.5)
plt.xlabel('$e_{10}$')
plt.show()

# Plot histrogram of measured angle errors
plt.hist(np.array(meas_angs_MA)[e_vals_mm<=0.4]-target_ang, histtype='step', range=(-0.4,0.4), bins=20, label='measured angle')
plt.legend()
plt.xlim(-0.4,0.4)
plt.xlabel('error in measured angle')
plt.ylabel('counts')
plt.show()

# %% [markdown]
# This looks very monotonic until reaching higher eccentricities. Maybe let's try a second iteration to get closer to target angle?

# %% [markdown]
# ## 2 iterations

# %%
target_ang = np.pi/3

# Get degen line parameters from metadata
base_params = grid_data_0['metadata']['base_params']
fid_params = grid_data_0['metadata']['fid_params']
fid_params['distance'] = 1
e_vals_4d = grid_data_0['metadata']['degen_params']['ecc10']

# Generate harmonics at fid point
harms = make_waveform(fid_params, 1/32, 20, 32*4096//2+1, approximant="TEOBResumS-Dali-Harms", n_ecc_harms=3)
wf_hjs_4d = []
for mode in [0,1,-1]:
    wf_hjs_4d.append(harms[mode].to_timeseries())

rho_1_fracs_0_v2 = []
rho_1_fracs_MA_v2 = []
rho_n1_fracs_0_v2 = []
rho_n1_fracs_MA_v2 = []
pc_fracs_0_v2 = []
pc_fracs_MA_v2 = []
meas_angs_MA_v2 = []
# Loop over each point on degen line
for i, e_val in enumerate(e_vals_4d):

    # Generate and match wf at MA=0
    param_dict = degen_point(e_val, base_params, fid_params)
    param_dict['mass_ratio'] = q_from_eta(param_dict['symmetric_mass_ratio'])
    param_dict['inverted_mass_ratio'] = 1/param_dict['mass_ratio']
    param_dict['total_mass'] = np.sum(component_masses_from_mchirp_q(param_dict['chirp_mass'], param_dict['mass_ratio']), axis=0)
    hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], param_dict['ecc10sqrd']**0.5,
                                         param_dict['chi_eff'], param_dict['chi_eff'], 10, 4096, tlen=32, to_fs=False)
    h = hp - 1j*hc
    match_cplx_0 = match_hn(wf_hjs_4d, h, 10)
    meas_ang_0 = (np.angle(match_cplx_0[1])-np.angle(match_cplx_0[0]))%(2*np.pi)
    MA = target_ang - meas_ang_0

    # Shift to f, e for required MA (using approx eqns w/o correction for now
    s_f_2pi =  10 - shifted_f(10, param_dict['ecc10sqrd']**0.5, param_dict['total_mass'], param_dict['inverted_mass_ratio'])
    s_f = 10 - s_f_2pi*MA/(2*np.pi)
    s_e = shifted_e(s_f, 10, param_dict['ecc10sqrd']**0.5)
    
    # Generate and match wf at required MA
    hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], s_e,
                                         param_dict['chi_eff'], param_dict['chi_eff'], s_f, 4096, tlen=32, to_fs=False)
    h = hp - 1j*hc
    match_cplx_MA = match_hn(wf_hjs_4d, h, 10)
    meas_ang_MA = (np.angle(match_cplx_MA[1])-np.angle(match_cplx_MA[0]))%(2*np.pi)
    MA_v2 = target_ang - meas_ang_MA + MA

    # Shift to f, e for required MA (using approx eqns w/o correction for now
    s_f_2pi =  10 - shifted_f(10, param_dict['ecc10sqrd']**0.5, param_dict['total_mass'], param_dict['inverted_mass_ratio'])
    s_f = 10 - s_f_2pi*MA_v2/(2*np.pi)
    s_e = shifted_e(s_f, 10, param_dict['ecc10sqrd']**0.5)
    
    # Generate and match wf at required MA
    hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], s_e,
                                         param_dict['chi_eff'], param_dict['chi_eff'], s_f, 4096, tlen=32, to_fs=False)
    h = hp - 1j*hc
    match_cplx_MA_v2 = match_hn(wf_hjs_4d, h, 10)
    meas_angs_MA_v2.append((np.angle(match_cplx_MA_v2[1])-np.angle(match_cplx_MA_v2[0]))%(2*np.pi))

    # Get phase consistent match fractions of both
    rho_1_fracs_0_v2.append(np.abs(match_cplx_0[1])/np.abs(match_cplx_0[0]))
    rho_1_fracs_MA_v2.append(np.abs(match_cplx_MA_v2[1])/np.abs(match_cplx_MA_v2[0]))
    rho_n1_fracs_0_v2.append(np.abs(match_cplx_0[2])/np.abs(match_cplx_0[0]))
    rho_n1_fracs_MA_v2.append(np.abs(match_cplx_MA_v2[2])/np.abs(match_cplx_MA_v2[0]))
    pc_fracs_0_v2.append(comb_harm_consistent(np.abs(match_cplx_0[:3]), np.angle(match_cplx_0[:3]), harms=[0,1,-1]))
    pc_fracs_MA_v2.append(comb_harm_consistent(np.abs(match_cplx_MA_v2[:3]), np.angle(match_cplx_MA_v2[:3]), harms=[0,1,-1]))

    print(f'\r{i+1} out of {len(e_vals_4d)} done.', end='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 target_ang = np.pi/3
#       3 # Get degen line parameters from metadata
# ----> 4 base_params = grid_data_0['metadata']['base_params']
#       5 fid_params = grid_data_0['metadata']['fid_params']
#       6 fid_params['distance'] = 1
#
# NameError: name 'grid_data_0' is not defined

# %%
# Metadata
e_vals_mm = grid_data_0['metadata']['degen_params']['ecc10']
fid_e = grid_data_0['metadata']['fid_params']['ecc10sqrd']**0.5

keys = ['h1_h0', 'h-1_h0', 'h1_h-1_h0']
labels = ['$\\rho_1$', '$\\rho_-1$', '$\\sqrt{\\rho_1^2+\\rho_{-1}^2}$']
cs = ['C0', 'C1', 'C2']
fracs_0_list = [rho_1_fracs_0, rho_n1_fracs_0, pc_fracs_0]
fracs_MA_list = [rho_1_fracs_MA_v2, rho_n1_fracs_MA_v2, pc_fracs_MA_v2]
for key, label, c, fracs_0, fracs_MA in zip(keys, labels, cs, fracs_0_list, fracs_MA_list):

    # Plot min/max region
    plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
    plt.plot(e_vals_mm, grid_data_0[f'{key}_max'], c=c, zorder=3/5, label=label)
    plt.plot(e_vals_mm, grid_data_0[f'{key}_min'], c=c, zorder=3/5)
    plt.fill_between(e_vals_mm, grid_data_0[f'{key}_min'], 
                     grid_data_0[f'{key}_max'], color=c, zorder=3/5, alpha=0.3)
    
    # Plot const MA and const ang lines
    plt.plot(e_vals_4d, fracs_0, c='r', alpha=0.7, label='const MA')
    plt.plot(e_vals_4d, fracs_MA, c='k', label='const angle')
    
    # Plot formatting
    plt.legend(frameon=False, loc=(0.35,0.50))
    plt.xlim(0,0.4)
    plt.ylim(0,0.85)
    plt.xlabel('$e_{10}$')
    plt.show()

# Plot all three constant angle lines on same plot
plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
for label, c, fracs_MA in zip(labels, cs, fracs_MA_list):
    plt.plot(e_vals_4d, fracs_MA, c=c, label=label)
plt.legend(frameon=False, loc=(0.35,0.50))
plt.xlim(0,0.4)
plt.ylim(0,0.85)
plt.xlabel('$e_{10}$')
plt.show()

# Plot measured angle at each eccentricity
plt.axhline(target_ang, c='k', ls='dashed', label='target angle')
plt.plot(e_vals_4d, meas_angs_MA, c='C1', ls='dashed', alpha=0.7, label='measured angle (1 iter)')
plt.plot(e_vals_4d, meas_angs_MA_v2, c='C0', label='measured angle (2 iter)')
plt.legend()
plt.xlim(0,0.4)
plt.ylim(target_ang-0.5, target_ang+0.5)
plt.xlabel('$e_{10}$')
plt.show()

# Plot histrogram of measured angle errors
plt.hist(np.array(meas_angs_MA)[e_vals_mm<=0.4]-target_ang, color='C1', alpha=0.7, histtype='step', range=(-0.4,0.4), bins=20, label='measured angle (1 iter)')
plt.hist(np.array(meas_angs_MA_v2)[e_vals_mm<=0.4]-target_ang, color='C0', histtype='step', range=(-0.4,0.4), bins=20,  label='measured angle (2 iter)')
plt.legend()
plt.xlim(-0.4,0.4)
plt.xlabel('error in measured angle')
plt.ylabel('counts')
plt.show()

# %% [markdown]
# This is definitely improved. Best way would likely be to iterate until below a certain tolerance. Would also probably do some smoothing to get rid of very small jumps.
#
# Just to make sure, will try shifted f, shifted e with generating additional wf to correct with s_factor (and just one iteration of shifting MA).

# %% [markdown]
# ## 1 iteration, s_factor

# %%
target_ang = np.pi/3

# Get degen line parameters from metadata
base_params = grid_data_0['metadata']['base_params']
fid_params = grid_data_0['metadata']['fid_params']
fid_params['distance'] = 1
e_vals_4d = grid_data_0['metadata']['degen_params']['ecc10']

# Generate harmonics at fid point
harms = make_waveform(fid_params, 1/32, 20, 32*4096//2+1, approximant="TEOBResumS-Dali-Harms", n_ecc_harms=3)
wf_hjs_4d = []
for mode in [0,1,-1]:
    wf_hjs_4d.append(harms[mode].to_timeseries())

rho_1_fracs_0 = []
rho_1_fracs_MA_test = []
rho_n1_fracs_0 = []
rho_n1_fracs_MA_test = []
pc_fracs_0 = []
pc_fracs_MA_test = []
meas_angs_MA_test = []
# Loop over each point on degen line
for i, e_val in enumerate(e_vals_4d):

    # Generate and match wf at MA=0
    param_dict = degen_point(e_val, base_params, fid_params)
    param_dict['mass_ratio'] = q_from_eta(param_dict['symmetric_mass_ratio'])
    param_dict['inverted_mass_ratio'] = 1/param_dict['mass_ratio']
    param_dict['total_mass'] = np.sum(component_masses_from_mchirp_q(param_dict['chirp_mass'], param_dict['mass_ratio']), axis=0)
    hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], param_dict['ecc10sqrd']**0.5,
                                         param_dict['chi_eff'], param_dict['chi_eff'], 10, 4096, tlen=32, to_fs=False)
    h = hp - 1j*hc
    match_cplx_0 = match_hn(wf_hjs_4d, h, 10)
    meas_ang_0 = (np.angle(match_cplx_0[1])-np.angle(match_cplx_0[0]))%(2*np.pi)
    MA = target_ang - meas_ang_0

    # Shift to f, e for required MA with additional wf call for s_factor
    s_f_max = shifted_f(10, param_dict['ecc10sqrd']**0.5, param_dict['total_mass'], param_dict['inverted_mass_ratio'])
    s_e_max = shifted_e(s_f_max, 10, param_dict['ecc10sqrd']**0.5)
    s_hp, s_hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], s_e_max,
                                             param_dict['chi_eff'], param_dict['chi_eff'], s_f_max, 4096, tlen=32, to_fs=False)
    s_h = s_hp - 1j*s_hc
    h_peaks_inds = np.diff(np.sign(np.diff(np.abs(h)))) < 0
    s_peaks_inds = np.diff(np.sign(np.diff(np.abs(s_h)))) < 0
    h_peaks = h.sample_times[1:-1][h_peaks_inds]
    s_peaks = s_h.sample_times[1:-1][s_peaks_inds]
    s_factor = 1/(1+(h_peaks[0]-s_peaks[1])/(h_peaks[1]-h_peaks[0]))
    s_f_2pi =  (10 - shifted_f(10, param_dict['ecc10sqrd']**0.5, param_dict['total_mass'], param_dict['inverted_mass_ratio']))*s_factor
    s_f = 10 - s_f_2pi*MA/(2*np.pi)
    s_e = shifted_e(s_f, 10, param_dict['ecc10sqrd']**0.5)
    
    # Generate and match wf at required MA
    hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], s_e,
                                         param_dict['chi_eff'], param_dict['chi_eff'], s_f, 4096, tlen=32, to_fs=False)
    h = hp - 1j*hc
    match_cplx_MA = match_hn(wf_hjs_4d, h, 10)
    meas_angs_MA_test.append((np.angle(match_cplx_MA[1])-np.angle(match_cplx_MA[0]))%(2*np.pi))

    # Get phase consistent match fractions of both
    rho_1_fracs_0.append(np.abs(match_cplx_0[1])/np.abs(match_cplx_0[0]))
    rho_1_fracs_MA_test.append(np.abs(match_cplx_MA[1])/np.abs(match_cplx_MA[0]))
    rho_n1_fracs_0.append(np.abs(match_cplx_0[2])/np.abs(match_cplx_0[0]))
    rho_n1_fracs_MA_test.append(np.abs(match_cplx_MA[2])/np.abs(match_cplx_MA[0]))
    pc_fracs_0.append(comb_harm_consistent(np.abs(match_cplx_0[:3]), np.angle(match_cplx_0[:3]), harms=[0,1,-1]))
    pc_fracs_MA_test.append(comb_harm_consistent(np.abs(match_cplx_MA[:3]), np.angle(match_cplx_MA[:3]), harms=[0,1,-1]))

    print(f'\r{i+1} out of {len(e_vals_4d)} done.', end='')
# Out:
# 151 out of 151 done.

# %%
# Metadata
e_vals_mm = grid_data_0['metadata']['degen_params']['ecc10']
fid_e = grid_data_0['metadata']['fid_params']['ecc10sqrd']**0.5

keys = ['h1_h0', 'h-1_h0', 'h1_h-1_h0']
labels = ['$\\rho_1$', '$\\rho_-1$', '$\\sqrt{\\rho_1^2+\\rho_{-1}^2}$']
cs = ['C0', 'C1', 'C2']
fracs_0_list = [rho_1_fracs_0, rho_n1_fracs_0, pc_fracs_0]
fracs_MA_list = [rho_1_fracs_MA_test, rho_n1_fracs_MA_test, pc_fracs_MA_test]
for key, label, c, fracs_0, fracs_MA in zip(keys, labels, cs, fracs_0_list, fracs_MA_list):

    # Plot min/max region
    plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
    plt.plot(e_vals_mm, grid_data_0[f'{key}_max'], c=c, zorder=3/5, label=label)
    plt.plot(e_vals_mm, grid_data_0[f'{key}_min'], c=c, zorder=3/5)
    plt.fill_between(e_vals_mm, grid_data_0[f'{key}_min'], 
                     grid_data_0[f'{key}_max'], color=c, zorder=3/5, alpha=0.3)
    
    # Plot const MA and const ang lines
    plt.plot(e_vals_4d, fracs_0, c='r', alpha=0.7, label='const MA')
    plt.plot(e_vals_4d, fracs_MA, c='k', label='const angle')
    
    # Plot formatting
    plt.legend(frameon=False, loc=(0.35,0.50))
    plt.xlim(0,0.4)
    plt.ylim(0,0.85)
    plt.xlabel('$e_{10}$')
    plt.show()

# Plot all three constant angle lines on same plot
plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
for label, c, fracs_MA in zip(labels, cs, fracs_MA_list):
    plt.plot(e_vals_4d, fracs_MA, c=c, label=label)
plt.legend(frameon=False, loc=(0.35,0.50))
plt.xlim(0,0.4)
plt.ylim(0,0.85)
plt.xlabel('$e_{10}$')
plt.show()

# Plot measured angle at each eccentricity
plt.axhline(target_ang, c='k', ls='dashed', label='target angle')
plt.plot(e_vals_4d, meas_angs_MA_test, alpha=0.7, label='measured angle')
plt.legend()
plt.xlim(0,0.4)
plt.ylim(target_ang-0.5, target_ang+0.5)
plt.xlabel('$e_{10}$')
plt.show()

# Plot histrogram of measured angle errors
plt.hist(np.array(meas_angs_MA_test)[e_vals_mm<=0.4]-target_ang, color='C2', histtype='step', range=(-0.4,0.4), bins=20, label='measured angle (1 iter, s_factor)')
plt.hist(np.array(meas_angs_MA)[e_vals_mm<=0.4]-target_ang, color='C1', histtype='step', range=(-0.4,0.4), bins=20, label='measured angle (1 iter)')
plt.hist(np.array(meas_angs_MA_v2)[e_vals_mm<=0.4]-target_ang, color='C0', histtype='step', range=(-0.4,0.4), bins=20, label='measured angle (2 iter)')
plt.legend()
plt.xlim(-0.4,0.4)
plt.xlabel('error in measured angle')
plt.ylabel('counts')
plt.show()

# %% [markdown]
# This is slightly better than just a single iteration by itself, but not as good as 2 iterations, so possibly not worth doing. May come point at higher iterations where it becomes better than additional iteration however.

# %% [markdown]
# ## Optimising

# %% [markdown]
# All we really care about are the higher eccentricities, say e=0.25-0.4, so let's restrict our attention to here to reduce computation times. Here will test iterating until certain tolerance (or max iterations reached), and whether to regenerate wf for s_factor in order to try and find the best balance of line smoothness and speed.

# %%
target_ang = np.pi/3
target_tol = 0.1
max_iter = 5

# Get degen line parameters from metadata
base_params = grid_data_0['metadata']['base_params']
fid_params = grid_data_0['metadata']['fid_params']
fid_params['distance'] = 1
e_vals_long = grid_data_0['metadata']['degen_params']['ecc10']
e_vals_med = e_vals_long[e_vals_long>=0.25]
e_vals_small = e_vals_med[e_vals_med<=0.4]

# Generate harmonics at fid point
harms = make_waveform(fid_params, 1/32, 20, 32*4096//2+1, approximant="TEOBResumS-Dali-Harms", n_ecc_harms=3)
wf_hjs_4d = []
for mode in [0,1,-1]:
    wf_hjs_4d.append(harms[mode].to_timeseries())

rho_1_fracs_small = []
rho_n1_fracs_small = []
pc_fracs_small = []
meas_angs_small = []
start = time.time()
# Loop over each point on degen line
for i, e_val in enumerate(e_vals_small):

    # Calculate parameters
    param_dict = degen_point(e_val, base_params, fid_params)
    param_dict['mass_ratio'] = q_from_eta(param_dict['symmetric_mass_ratio'])
    param_dict['inverted_mass_ratio'] = 1/param_dict['mass_ratio']
    param_dict['total_mass'] = np.sum(component_masses_from_mchirp_q(param_dict['chirp_mass'], param_dict['mass_ratio']), axis=0)

    # Iterate to target MA
    tol = 2*np.pi
    current_iter = 0
    MA = 0
    while tol > target_tol and current_iter < max_iter:

        # Shift to f, e for required MA (using approx eqns w/o correction for now
        s_f_2pi =  10 - shifted_f(10, param_dict['ecc10sqrd']**0.5, param_dict['total_mass'], param_dict['inverted_mass_ratio'])
        s_f = 10 - s_f_2pi*MA/(2*np.pi)
        s_e = shifted_e(s_f, 10, param_dict['ecc10sqrd']**0.5)

        # Generate and match wf at requested MA
        hp, hc = generate_eccentric_waveform(param_dict['total_mass'], param_dict['inverted_mass_ratio'], s_e,
                                             param_dict['chi_eff'], param_dict['chi_eff'], 10, 4096, tlen=32, to_fs=False)
        h = hp - 1j*hc
        match_cplx = match_hn(wf_hjs_4d, h, 10)
        phi_0 = np.angle(match_cplx[0])%(2*np.pi)
        phi_1 = np.angle(match_cplx[1])%(2*np.pi)
        meas_ang = (phi_1-phi_0)%(2*np.pi)

        # Update MA, tolerance, and iteration count
        MA += target_ang - meas_ang
        MA = MA%(2*np.pi)
        tol = np.abs(meas_ang-target_ang)
        current_iter += 1

    # Save data
    rho_1_fracs_small.append(np.abs(match_cplx[1])/np.abs(match_cplx[0]))
    rho_n1_fracs_small.append(np.abs(match_cplx[2])/np.abs(match_cplx[0]))
    pc_fracs_small.append(comb_harm_consistent(np.abs(match_cplx[:3]), np.angle(match_cplx[:3]), harms=[0,1,-1]))
    meas_angs_small.append(meas_ang)

    print(f'\r{i+1} out of {len(e_vals_small)} done.', end='')

end = time.time()
print(f'\nCompleted in {end-start} seconds.')
# Out:
# 46 out of 46 done.
# Completed in 135.06086421012878 seconds.

# %%
# Metadata
e_vals_mm = grid_data_0['metadata']['degen_params']['ecc10']
fid_e = grid_data_0['metadata']['fid_params']['ecc10sqrd']**0.5

keys = ['h1_h0', 'h-1_h0', 'h1_h-1_h0']
labels = ['$\\rho_1$', '$\\rho_-1$', '$\\sqrt{\\rho_1^2+\\rho_{-1}^2}$']
cs = ['C0', 'C1', 'C2']
fracs_MA_list = [rho_1_fracs_small, rho_n1_fracs_small, pc_fracs_small]
for key, label, c, fracs_MA in zip(keys, labels, cs, fracs_MA_list):

    # Plot min/max region
    plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
    plt.plot(e_vals_mm, grid_data_0[f'{key}_max'], c=c, zorder=3/5, label=label)
    plt.plot(e_vals_mm, grid_data_0[f'{key}_min'], c=c, zorder=3/5)
    plt.fill_between(e_vals_mm, grid_data_0[f'{key}_min'], 
                     grid_data_0[f'{key}_max'], color=c, zorder=3/5, alpha=0.3)
    
    # Plot const ang line
    plt.plot(e_vals_small, fracs_MA, c='k', label='const angle')
    
    # Plot formatting
    plt.legend(frameon=False, loc=(0.35,0.50))
    plt.xlim(0,0.4)
    plt.ylim(0,0.85)
    plt.xlabel('$e_{10}$')
    plt.show()

# Plot all three constant angle lines on same plot
plt.axvline(fid_e, ls='dashed', c='C4', zorder=5/5, label='Fiducial $e_{10}$')
for label, c, fracs_MA in zip(labels, cs, fracs_MA_list):
    plt.plot(e_vals_small, fracs_MA, c=c, label=label)
plt.legend(frameon=False, loc=(0.35,0.50))
plt.xlim(0,0.4)
plt.ylim(0,0.85)
plt.xlabel('$e_{10}$')
plt.show()

# Plot measured angle at each eccentricity
plt.axhline(target_ang, c='k', ls='dashed', label='target angle')
plt.plot(e_vals_small, meas_angs_small, c='C1', ls='dashed', alpha=0.7, label='measured angle')
plt.legend()
plt.xlim(0,0.4)
plt.ylim(target_ang-0.5, target_ang+0.5)
plt.xlabel('$e_{10}$')
plt.show()

# Plot histrogram of measured angle errors
plt.hist(np.array(meas_angs_small)-target_ang, color='C1', alpha=0.7, histtype='step', range=(-0.4,0.4), bins=20, label='measured angle')
plt.legend()
plt.xlim(-0.4,0.4)
plt.xlabel('error in measured angle')
plt.ylabel('counts')
plt.show()
