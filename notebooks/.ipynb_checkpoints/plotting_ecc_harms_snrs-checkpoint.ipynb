# %%
import plotsettings
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.rcParams["text.usetex"] = False

# %%
filename2 = '../data/injection_files/injections_10000_CMC_mass_redshift_ecc_distribution_2_zero_noise_correct_orthonormalization_snr_threshold_8.dat'
filename1 = '../data/injection_files/injections_10000_CMC_mass_redshift_ecc_distribution_zero_noise_correct_orthonormalization_snr_threshold_8.dat'
filename3 = '../data/injection_files/injections_100000_CMC_mass_redshift_ecc_distribution_zero_noise_correct_orthonormalization_snr_threshold_8.dat'
filename4 = '../data/injection_files/injections_500000_CMC_mass_redshift_ecc_distribution_1_zero_noise_correct_orthonormalization_snr_threshold_8.dat'
filename5 = '../data/injection_files/injections_500000_CMC_mass_redshift_ecc_distribution_2_zero_noise_correct_orthonormalization_snr_threshold_8.dat'

# %%
filenames = [filename1, filename2, filename3, filename4, filename5]

# %%
data_snr = pd.DataFrame()
for filename in filenames:
    data = pd.read_csv(
        filename,
        sep=' '
    )
    data_snr = pd.concat([data_snr, data], ignore_index=True)

# %%
data_snr
# Out:
#             chi_1     chi_2  theta_jn       dec        ra       psi     phase  \
# 0        0.023986  0.132025  0.414202  0.005782  5.680618  2.042083  3.731079
# 1       -0.076818  0.094012  0.935984  0.453957  0.266484  2.342196  4.723288
# 2        0.022495  0.033761  1.408042 -0.514957  0.082688  1.161626  4.824794
# 3        0.040801  0.435882  0.803365 -0.193918  4.296829  2.158365  0.148371
# 4        0.166000  0.011109  1.239956  0.238330  0.451286  1.278281  1.938379
# ...           ...       ...       ...       ...       ...       ...       ...
# 1119995  0.464388  0.019926  0.642672 -0.763858  0.643403  0.063854  4.695084
# 1119996  0.072811 -0.058040  1.667407 -0.220824  5.931717  1.023810  5.793844
# 1119997 -0.135992 -0.712797  1.607039  0.435926  5.467685  2.125381  3.523830
# 1119998  0.504608 -0.104829  2.359341  0.843529  1.039537  2.423442  1.980897
# 1119999  0.357989 -0.524863  0.531865  0.961595  3.309906  0.748808  3.068133
#
#          geocent_time   mass_1    mass_2  ...  rho_-1_L1  rho_2_L1  rho_0_V1  \
# 0        1.677672e+09  41.6058  40.02770  ...        NaN       NaN       NaN
# 1        1.677672e+09  13.1828  12.86860  ...        NaN       NaN       NaN
# 2        1.677672e+09  13.2597  12.10900  ...        NaN       NaN       NaN
# 3        1.677672e+09  16.3429  15.50810  ...        NaN       NaN       NaN
# 4        1.677672e+09  32.2779  28.73460  ...        NaN       NaN       NaN
# ...               ...      ...       ...  ...        ...       ...       ...
# 1119995  1.677672e+09  26.2727  17.50730  ...        NaN       NaN       NaN
# 1119996  1.677672e+09  32.9120  25.32810  ...        NaN       NaN       NaN
# 1119997  1.677672e+09  15.3809  13.91920  ...        NaN       NaN       NaN
# 1119998  1.677672e+09  14.4999   7.53645  ...        NaN       NaN       NaN
# 1119999  1.677672e+09  13.0999   7.47381  ...        NaN       NaN       NaN
#
#          rho_1_V1  rho_-1_V1  rho_2_V1  net_snr_0  net_snr_1  net_snr_-1  \
# 0             NaN        NaN       NaN        NaN        NaN         NaN
# 1             NaN        NaN       NaN        NaN        NaN         NaN
# 2             NaN        NaN       NaN        NaN        NaN         NaN
# 3             NaN        NaN       NaN        NaN        NaN         NaN
# 4             NaN        NaN       NaN        NaN        NaN         NaN
# ...           ...        ...       ...        ...        ...         ...
# 1119995       NaN        NaN       NaN        NaN        NaN         NaN
# 1119996       NaN        NaN       NaN        NaN        NaN         NaN
# 1119997       NaN        NaN       NaN        NaN        NaN         NaN
# 1119998       NaN        NaN       NaN        NaN        NaN         NaN
# 1119999       NaN        NaN       NaN        NaN        NaN         NaN
#
#          net_snr_2
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 
# 1119991  0.980220   0.400231  0.102737  10.766455   1.162902    0.475348
#
#          net_snr_2
# 6         0.109243
# 14        0.029762
# 50        0.206440
# 65        0.241569
# 115       0.673616
# ...            ...
# 1119923   0.118972
# 1119958   0.387213
# 1119959   0.051162
# 1119970   0.020428
# 1119991   0.121133
#
# [36462 rows x 40 columns]

# %%
df_to_plot.keys()
# Out:
# Index(['chi_1', 'chi_2', 'theta_jn', 'dec', 'ra', 'psi', 'phase',
#        'geocent_time', 'mass_1', 'mass_2', 'redshift', 'eccentricity_10Hz',
#        'chi_1.1', 'chi_2.1', 'theta_jn.1', 'dec.1', 'ra.1', 'psi.1', 'phase.1',
#        'geocent_time.1', 'mass_1.1', 'mass_2.1', 'redshift.1',
#        'eccentricity_10Hz.1', 'rho_0_H1', 'rho_1_H1', 'rho_-1_H1', 'rho_2_H1',
#        'rho_0_L1', 'rho_1_L1', 'rho_-1_L1', 'rho_2_L1', 'rho_0_V1', 'rho_1_V1',
#        'rho_-1_V1', 'rho_2_V1', 'net_snr_0', 'net_snr_1', 'net_snr_-1',
#        'net_snr_2'],
#       dtype='object')

# %%
snr_total = np.sqrt(
    df_to_plot['net_snr_1'] ** 2 + df_to_plot['net_snr_-1'] ** 2 + \
    df_to_plot['net_snr_2'] ** 2 + df_to_plot['net_snr_0'] ** 2
)
snr_harms = np.sqrt(
    df_to_plot['net_snr_1'] ** 2 + df_to_plot['net_snr_-1'] ** 2 + \
    df_to_plot['net_snr_2'] ** 2
)

# %%
total_mass = df_to_plot['mass_1']+df_to_plot['mass_2']
mass_ratio = df_to_plot['mass_1']/df_to_plot['mass_2']

# %%
plt.figure(figsize=(10, 6))
plt.scatter(
    df_to_plot['eccentricity_10Hz'], (snr_harms/df_to_plot['net_snr_0']), 
    c=total_mass, s=50 
)
plt.xlabel(r'$e_{\rm{10}}$')
plt.ylabel(r'$\rho_{\rm{perp}}/\rho_0$')
plt.colorbar(label=r'$M_{\rm{total}}$')
plt.yscale('log')
plt.xscale('log')
plt.show()

# %%
idx = snr_harms >= 3
idx.sum()
# Out:
# 2784

# %%
plt.figure(figsize=(10, 6))
plt.scatter(
    df_to_plot['eccentricity_10Hz'][idx], (snr_harms/df_to_plot['net_snr_0'])[idx], 
    c=total_mass[idx], s=50 
)
plt.xlabel(r'$e_{\rm{10}}$')
plt.ylabel(r'$\rho_{\rm{perp}}/\rho_0$')
plt.colorbar(label=r'$M_{\rm{total}}$')
plt.yscale('log')
plt.xscale('log')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(
    df_to_plot['eccentricity_10Hz'][idx], df_to_plot['net_snr_0'][idx], 
    s=50, label='0'
)
plt.scatter(
    df_to_plot['eccentricity_10Hz'][idx], snr_harms[idx], 
    s=50, label='(1, -1, 2)'
)
plt.xlabel(r'$e_{\rm{10}}$')
plt.legend()
plt.ylabel(r'$\rho$')
plt.yscale('log')
plt.show()

# %%
plt.figure(figsize=(8, 6))
# plt.scatter(
#     df_to_plot['eccentricity_10Hz'][idx], df_to_plot['net_snr_0'][idx], 
#     s=50, label='0'
# )
plt.scatter(
    df_to_plot['eccentricity_10Hz'][idx], mass_ratio[idx], c=snr_harms[idx], 
    s=total_mass[idx] * 1.5
)
plt.xlabel(r'$e_{\rm{10}}$')
plt.ylabel(r'$q$')
# plt.legend()
plt.colorbar(label=r'$\rho_{\rm{perp}}$')
# plt.yscale('log')
plt.show()

# %%
plt.figure(figsize=(10, 7))
for mode in [0, 1, -1, 2]:
    plt.scatter(
        df_to_plot['eccentricity_10Hz'][idx], df_to_plot[f'net_snr_{mode}'][idx], 
        s=50, label=mode
    )
plt.xlabel(r'$e_{\rm{10}}$')
plt.legend()
plt.ylabel(r'$\rho$')
plt.yscale('log')
plt.show()

# %%
# Set up bins and common kwargs
bins = np.linspace(-3.5, np.log10(df_to_plot['eccentricity_10Hz'].max()), 30)
kwargs = dict(bins=bins, histtype='step', density=True, lw=2)

hist_all = plt.hist(
    np.log10(data_snr['eccentricity_10Hz']), label=r'CMC', 
    **kwargs
)
hist_all = plt.hist(
    np.log10(df_to_plot['eccentricity_10Hz']), label=r'$\rho_{\rm{Total}} \geq 8$', 
    **kwargs
)
hist_det = plt.hist(
    np.log10(df_to_plot['eccentricity_10Hz'][idx]), label=r'$\rho_{\rm{Perp}} \geq 3$',
    **kwargs
)

plt.xlabel(r'$\log_{10}(e_{\mathrm{10Hz}})$', fontsize=18)
plt.ylabel('Normalized Count', fontsize=18)
plt.title('Eccentricity Distribution', fontsize=20)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
frac = len(df_to_plot)/len(data_snr) * 100
print('The faction of detected events (%) = ', frac)
frac = idx.sum()/len(df_to_plot) * 100
print('The faction of detectable eccentric harmonics out of detected events (%) = ', frac)
# Out:
# The faction of detected events (%) =  3.255535714285714
# The faction of detectable eccentric harmonics out of detected events (%) =  7.635346388020404

# %%
idx1 = np.argmax(hist_all[0])
10 ** hist_all[1][idx1]
# Out:
# 0.014022093140707771

# %%
idx1 = np.argmax(hist_det[0])
10 ** hist_det[1][idx1]
# Out:
# 0.2758908058871493

# %%
kwargs = dict(bins='auto', density=True, log=True, lw=2)
plt.hist(snr_harms, **kwargs)
plt.axvline(3, c='r')
# plt.xscale('log')
plt.show()

# %%
# Set up bins and common kwargs
bins = np.linspace(df_to_plot['eccentricity_10Hz'].min(), df_to_plot['eccentricity_10Hz'].max(), 40)
kwargs = dict(bins=bins, log=True, histtype='step', lw=2)

hist_all = plt.hist(
    data_snr['eccentricity_10Hz'], label=r'CMC', 
    **kwargs
)
hist_all = plt.hist(
    df_to_plot['eccentricity_10Hz'], label=r'$\rho_{\rm{Total}} \geq 8$', 
    **kwargs
)
hist_det = plt.hist(
    df_to_plot['eccentricity_10Hz'][idx], label=r'$\rho_{\rm{Perp}} \geq 3$',
    **kwargs
)

plt.xlabel(r'$e_{\mathrm{10Hz}}$', fontsize=18)
plt.ylabel('Count', fontsize=18)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
kwargs = dict(bins=100, log=True, lw=2, alpha=0.5)
plt.hist(snr_total, label='Observed total', **kwargs)
plt.hist(snr_total[idx], label='Observed eccentric', **kwargs)
plt.legend(loc='best')
plt.xlabel('Network SNR')
plt.ylabel('Count')
plt.show()

# %%
print('The median eccentricity in the observed population is %.2f' % np.median(df_to_plot['eccentricity_10Hz']))
print('The median eccentricity in observed eccentric population is %.2f' % np.median(df_to_plot['eccentricity_10Hz'][idx]))
# Out:
# The median eccentricity in the observed population is 0.03
# The median eccentricity in observed eccentric population is 0.35

# %%
print('The median SNR in the observed population is %.2f' % np.median(snr_total))
print('The median SNR in observed eccentric population is %.2f' % np.median(snr_total[idx]))
# Out:
# The median SNR in the observed population is 10.57
# The median SNR in observed eccentric population is 15.95
